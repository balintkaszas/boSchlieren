# %% [markdown]
# ## A motor frekvencia - feszültség karakterisztikája:
# ### 1.) Tracker, gerjesztés adatsorai
# | Filenév        |    Feszültség        | Frekvencia  | Rámpa|
# | ------------- |-------------| -----| ------- |
# | VID_20190207_141951     | 4V | 12T | nem |

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal
import scipy as sp
import scipy.fftpack

# %%
src = 'D:Interfacial waves resonance videos/'

# %%
dat = np.loadtxt('%s143736/res.dat' %src)
dat[:,1] = dat[:,1] - np.average(dat[:,1])
#L = dat[:,1]*scipy.signal.windows.hann(len(dat))

temp_fft = np.fft.rfft(dat[:,1])

def abs2(x):
    return x.real**2 + x.imag**2

selfconvol=np.fft.irfft(abs2(temp_fft), norm="ortho")
selfconvol=selfconvol/selfconvol[0]

temp_psd = np.abs(temp_fft) ** 2
fftfreq = np.fft.fftfreq(len(temp_psd), dt)

# %%
dt = dat[:,0][1]-dat[:,0][0]
print(dt)
# Out:
# 0.03342222222

# %%
fig, ax = plt.subplots(1, 2, figsize=(8, 4))
ax[0].plot(dat[:,0], dat[:,1], 'o')
ax[0].set_xlabel('Time [s]')
ax[0].set_ylabel('Ampl [m]')
ax[1].plot(1./fftfreq,temp_fft, '--o')
m= np.argmax(temp_fft)
ax[0].set_xlim(10, 15)
print(1./fftfreq[m])
# Out:
# C:\Users\balin\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in true_divide
#   """
# C:\Users\balin\Anaconda3\lib\site-packages\numpy\core\numeric.py:501: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# 1.1553819406249972

# %%
from scipy.signal import find_peaks

peaks, _ = find_peaks(np.abs(dat[:,1]), height=18)
plt.plot(np.diff(peaks*dt), "o")

# %%
dt = dat[:,0][1]-dat[:,0][0]
print(dt)
T = 2./dt
print(T)
N = len(dat)
t = np.linspace(0., N*dt, N)
f = np.linspace(0., T, N//2)
from scipy.fftpack import fft, irfft, ifft
asd = fft(dat[:,1])
plt.plot(2.*np.pi/f, 2.0/N * np.abs(asd[0:N//2]), 'o')
plt.xlim(0.,10)
#plt.plot(t, dat[:,1])
# Out:
# 0.033611110999999916
# 59.50413242811298
# C:\Users\balin\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: RuntimeWarning: divide by zero encountered in true_divide
#   # Remove the CWD from sys.path while we load stuff.
# (0.0, 10)

# %%
# Out:
# 0.6666666666666666

# %%
freqs, psd = scipy.signal.welch(dat[:,1], fs=2./dt, window='hamming')

# %%
plt.plot(freqs, psd/dat.size**2,  'o' , color='r')
#1./freqs
#plt.xlim(0.,1.)

# %%
selfconvol=np.fft.irfft(psd, norm="ortho")
selfconvol=selfconvol/selfconvol[0]

# %%
plt.plot(dat[:,0], dat[:,1])
#plt.plot(np.linspace(0., dat[:,0][-1], len(selfconvol)), selfconvol)
plt.xlim(0.4,33.5
        )

print("Period: 33.5-0.4/6 =", (33.5-0.4)/6., "s")
# Out:
# Period: 33.5-0.4/6 = 5.516666666666667 s

# %%
dat = np.loadtxt('%s142317/res.dat' %src)
dat[:,1] = dat[:,1] - np.average(dat[:,1])

# %%
plt.plot(dat[:,0], dat[:,1])
#plt.plot(np.linspace(0., dat[:,0][-1], len(selfconvol)), selfconvol)
plt.xlim(6,19.5
        )

print("Period: 33.5-0.4/6 =", (19.5-6.)/3., "s")
# Out:
# Period: 33.5-0.4/6 = 4.5 s

# %%
dat = np.loadtxt('%s143947/res.dat' %src)
#dat[:,1] = dat[:,1] - np.average(dat[:,1])
plt.plot(dat[:,0], dat[:,1])
#plt.plot(np.linspace(0., dat[:,0][-1], len(selfconvol)), selfconvol)
plt.xlim(6, 29.2)

print("Period: 29.2-6/6 =", (29.2-6.)/6., "s")
# Out:
# Period: 29.2-6/6 = 3.8666666666666667 s

# %%
dat = np.loadtxt('%s144102/res.dat' %src)
#dat[:,1] = dat[:,1] - np.average(dat[:,1])
plt.plot(dat[:,0], dat[:,1])
#plt.plot(np.linspace(0., dat[:,0][-1], len(selfconvol)), selfconvol)
plt.xlim(3, 29.9)


print("Period: 29.9-3/8 =", (29.9-3.)/8., "s")
# Out:
# Period: 29.9-3/8 = 3.3625 s

# %%
dat = np.loadtxt('%s145340/res.dat' %src)
#dat[:,1] = dat[:,1] - np.average(dat[:,1])
plt.plot(dat[:,0], dat[:,1])
#plt.plot(np.linspace(0., dat[:,0][-1], len(selfconvol)), selfconvol)
plt.xlim(1.7, 19.3)


print("Period: 19.3-1.7/6 =", (19.3-1.7)/6., "s")
# Out:
# Period: 19.3-1.7/6 = 2.9333333333333336 s

# %%
dat = np.loadtxt('%s145453/res.dat' %src)
#dat[:,1] = dat[:,1] - np.average(dat[:,1])
plt.plot(dat[:,0], dat[:,1])
#plt.plot(np.linspace(0., dat[:,0][-1], len(selfconvol)), selfconvol)
plt.xlim(3.4, 10.9)


print("Period: 10.9-3.4/3 =", (10.9-3.4)/3., "s")
# Out:
# Period: 10.9-3.4/3 = 2.5 s

# %%
dat = np.loadtxt('%s143614/res.dat' %src)
#dat[:,1] = dat[:,1] - np.average(dat[:,1])
plt.plot(dat[:,0], dat[:,1])
#plt.plot(np.linspace(0., dat[:,0][-1], len(selfconvol)), selfconvol)
plt.xlim(0.4, 39.3)


print("Period: 39.3-0.4/6 =", (39.3-0.4)/6., "s")
# Out:
# Period: 39.3-0.4/6 = 6.483333333333333 s

# %%
V = [4.,4.5, 5., 5.5, 6., 7., 8]
T = [6.48, 5.51, 4.5, 3.87, 3.36, 2.93, 2.5]
plt.plot(V, T, 'o')
